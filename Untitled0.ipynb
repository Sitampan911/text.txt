# %% [markdown]
# <a href="https://colab.research.google.com/github/Sitampan911/text.txt/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sapa_nama(nama):
    print(f"Halo {nama}, selamat belajar Python!")

sapa_nama("Daniel Christian S")
# Out:
# Halo Daniel Christian S, selamat belajar Python!
