# %% [markdown]
# <a href="https://colab.research.google.com/github/Sitampan911/text.txt/blob/main/___.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1TODO
firstName = "DANIEL"
lastName = "CHRISTIAN SITANGGANG"
age = 21
isMarried = False

print("nama depan :", firstName)
print("nama belakang :", lastName)
print("umur :", age)
print("status menikah :", isMarried)
# Out:
# nama depan : DANIEL
# nama belakang : CHRISTIAN SITANGGANG
# umur : 21
# status menikah : False

# %%
#2TODO
data_diri = {
    "firstName": "DANIEL",
    "lastName": "CHRISTIAN SITANGGANG",
    "age": 21,
    "isMarried": False
}
print("Data Diri:", data_diri)
print("\n=== BIODATA ===")
print(f"Nama Depan       : {data_diri['firstName']}")
print(f"Nama Belakang    : {data_diri['lastName']}")
print(f"Umur             : {data_diri['age']} tahun")
print(f"Status Pernikahan: {'Sudah Menikah' if data_diri['isMarried'] else 'Belum Menikah'}")
# Out:
# Data Diri: {'firstName': 'DANIEL', 'lastName': 'CHRISTIAN SITANGGANG', 'age': 21, 'isMarried': False}
#
# === BIODATA ===
# Nama Depan       : DANIEL
# Nama Belakang    : CHRISTIAN SITANGGANG
# Umur             : 21 tahun
# Status Pernikahan: Belum Menikah

# %%
#3TODO

inspeksi = [
    "pemahaman terhadap rencana dan desain",
    "ketersediaan bahan dan peralatan",
    "pengawasan pekerjaan",
    "kualitas konstruksi",
    "keselamatan kerja",
    "koordinasi dengan pemilik proyek"
]
print("daftar inspeksi:")
for item in inspeksi:
    print("-", item)
# Out:
# daftar inspeksi:
# - pemahaman terhadap rencana dan desain
# - ketersediaan bahan dan peralatan
# - pengawasan pekerjaan
# - kualitas konstruksi
# - keselamatan kerja
# - koordinasi dengan pemilik proyek

# %%
#4_TODO

startTime = {
"HH": 9,
"mm": 23,
"ss": 57
}


endTime = {
"HH": 15,
"mm": 25,
"ss": 43
}


print("Waktu Datang :", f"{startTime['HH']:02d}:{startTime['mm']:02d}:{startTime['ss']:02d}")
print("Waktu Pulang :", f"{endTime['HH']:02d}:{endTime['mm']:02d}:{endTime['ss']:02d}")
# Out:
# Waktu Datang : 09:23:57
# Waktu Pulang : 15:25:43

# %%
#5TODO

katalog_A = {"Laptop", "Smartphone", "Tablet", "Earphone"}
katalog_B = {"Smartwatch", "Smartphone", "Laptop", "Kamera"}
produk_diskon = ("Laptop", "Smartwatch", "Kamera", "Charger")

katalog_lengkap = katalog_A.union(katalog_B)
print("Katalog Lengkap:", katalog_lengkap)

produk_promo_aktif = katalog_lengkap.intersection(produk_diskon)
print("Produk Promo Aktif:", produk_promo_aktif)
# Out:
# Katalog Lengkap: {'Laptop', 'Kamera', 'Smartphone', 'Smartwatch', 'Earphone', 'Tablet'}
# Produk Promo Aktif: {'Laptop', 'Kamera', 'Smartwatch'}
